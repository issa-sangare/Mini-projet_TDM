# %%
pip install PyQt5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.6 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 KB 1.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 705.6 kB/s eta 0:00:0000:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyQt5-tools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 1.7 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 KB 795.5 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 MB 401.3 kB/s eta 0:00:000:0100:02
# ...
#   Attempting uninstall: pyqt5
#     Found existing installation: PyQt5 5.15.10
#     Uninstalling PyQt5-5.15.10:
#       Successfully uninstalled PyQt5-5.15.10
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog
class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: silver;")
        
        self.setWindowTitle("Compression Image")

        # Créer un label pour afficher le texte
        self.label = QLabel("L'extension .IRM", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Définir le label comme widget central
        self.setCentralWidget(self.label)

        # Définir la taille de la fenêtre
        self.resize(700, 500)
        # Définir la couleur d'arrière-plan
        self.setStyleSheet("background-color: #333333;")   #remplacer #333333 par black pour choisir la couleur la plus belle


        # Créer un widget pour contenir les boutons
        button_widget = QWidget()

        # Créer un layout vertical pour les boutons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Bouton pour choisir un fichier
        choose_button = QPushButton("Choisir un fichier")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Créer un layout horizontal pour les boutons de compression et de décompression
        compress_decompress_layout = QHBoxLayout()

        # Bouton pour compression
        compress_button = QPushButton("Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Bouton pour décompression
        decompress_button = QPushButton("Décompression")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Ajouter le layout horizontal au layout vertical
        button_layout.addLayout(compress_decompress_layout)

        # Ajouter le widget de boutons à la fenêtre principale
        self.setCentralWidget(button_widget)

        # Connexion des signaux des boutons à leurs slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.decompress_image)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choisir une image", "", "Images (*.png *.jpg *.jpeg *.bmp *.gif)", options=options)
        if file_name:
            print("Fichier sélectionné :", file_name)

    def compress_image(self):
        print("Compression en cours...")

    def decompress_image(self):
        print("Décompression en cours...")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# /tmp/ipykernel_40023/3249221562.py:3: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow):
# QSocketNotifier: Can only be used with threads started with QThread
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# ...

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog, QMessageBox

class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: silver;")
        
        self.setWindowTitle("Compression Image")

        # Créer un label pour afficher le texte
        self.label = QLabel("L'extension .IRM", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Définir le label comme widget central
        self.setCentralWidget(self.label)

        # Définir la taille de la fenêtre
        self.resize(700, 500)
        # Définir la couleur d'arrière-plan
        self.setStyleSheet("background-color: #333333;")   #remplacer #333333 par black pour choisir la couleur la plus belle


        # Créer un widget pour contenir les boutons
        button_widget = QWidget()

        # Créer un layout vertical pour les boutons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Bouton pour choisir un fichier
        choose_button = QPushButton("Choisir un fichier")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Créer un layout horizontal pour les boutons de compression et de décompression
        compress_decompress_layout = QHBoxLayout()

        # Bouton pour compression
        compress_button = QPushButton("Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Bouton pour décompression
        decompress_button = QPushButton("Décompression")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Ajouter le layout horizontal au layout vertical
        button_layout.addLayout(compress_decompress_layout)

        # Ajouter le widget de boutons à la fenêtre principale
        self.setCentralWidget(button_widget)

        # Connexion des signaux des boutons à leurs slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.decompress_image)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choisir une image", "", "Images (*.png *.jpg *.jpeg *.bmp *.gif)", options=options)
        if file_name:
            print("Fichier sélectionné :", file_name)

    def compress_image(self):
        print("Compression en cours...")

    def decompress_image(self):
        print("Décompression en cours...")
        # Calculer le MSE et le taux de compression
        mse = 0.05  # Exemple de valeur de MSE
        compression_rate = 0.75  # Exemple de taux de compression
        # Afficher les valeurs dans une boîte de dialogue
        QMessageBox.information(self, "Résultats", f"MSE : {mse}\nTaux de compression : {compression_rate}")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# /tmp/ipykernel_41180/2169240904.py:4: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow):
# QSocketNotifier: Can only be used with threads started with QThread
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# ...

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog, QLineEdit, QMessageBox
from PyQt5.QtGui import QPixmap  # Added QPixmap import
from PIL import Image

class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: #333333;")
        self.setWindowTitle("Image Compression")

        # Create a label to display the text
        self.label = QLabel("Image Extension", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Set the label as the central widget
        self.setCentralWidget(self.label)

        # Set the window size
        self.resize(700, 500)

        # Create a widget to contain buttons and text fields
        main_widget = QWidget()

        # Create a vertical layout for buttons and text fields
        main_layout = QVBoxLayout(main_widget)
        main_layout.setAlignment(Qt.AlignTop)

        # Create a gray frame to enclose the labels
        frame_style = "border: 2px solid gray; border-radius: 5px; background-color: #777777;"
        path_frame = QWidget()
        path_frame.setStyleSheet(frame_style)
        path_layout = QVBoxLayout(path_frame)

        # Add the label for the image path
        path_label = QLabel("Image Path:", self)
        path_label.setStyleSheet("color: white;")
        path_layout.addWidget(path_label)

        # Text field to display the image path
        self.image_path_field = QLineEdit(self)
        self.image_path_field.setReadOnly(True)
        self.image_path_field.setStyleSheet("background-color: gray; color: white;")  
        path_layout.addWidget(self.image_path_field)

        # Add the path frame to the main window
        main_layout.addWidget(path_frame)

        # Create a gray frame to enclose the labels
        name_frame = QWidget()
        name_frame.setStyleSheet(frame_style)
        name_layout = QVBoxLayout(name_frame)

        # Add the label for the image name
        name_label = QLabel("Image Name:", self)
        name_label.setStyleSheet("color: white;")
        name_layout.addWidget(name_label)

        # Text field to display the image name
        self.image_name_field = QLineEdit(self)
        self.image_name_field.setReadOnly(True)
        self.image_name_field.setStyleSheet("background-color: gray; color: white;")  
        name_layout.addWidget(self.image_name_field)

        # Add the name frame to the main window
        main_layout.addWidget(name_frame)

        # Create a widget to contain buttons
        button_widget = QWidget()

        # Create a vertical layout for buttons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Button to choose a file
        choose_button = QPushButton("Browse")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Button to display image information
        info_button = QPushButton("Information")
        info_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(info_button)

        # Add the button layout to the main window
        main_layout.addWidget(button_widget)

        # Buttons to choose the number of colors
        colors_button_layout = QHBoxLayout()
        palette_label = QLabel("Select the number of colors for the palette:", self)
        palette_label.setStyleSheet("color: white;")
        colors_button_layout.addWidget(palette_label)
        for num in [32, 64, 128]:
            button = QPushButton(str(num))
            button.clicked.connect(lambda _, n=num: self.set_num_colors(n))
            colors_button_layout.addWidget(button)

        # Add the color palette layout to the main window
        main_layout.addLayout(colors_button_layout)

        # Create a horizontal layout for compression and decompression buttons
        compress_decompress_layout = QHBoxLayout()

        # Button for compression
        compress_button = QPushButton("Start Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Button for decompression
        decompress_button = QPushButton("Save image.irm")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Add the horizontal layout to the vertical layout
        button_layout.addLayout(compress_decompress_layout)

        # Add the button widget to the main window
        main_layout.addWidget(button_widget)

        # Connect button signals to slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.decompress_image)
        info_button.clicked.connect(self.show_image_info)

        # Create a layout for "Original image" and "IRM Image" labels
        label_layout = QHBoxLayout()
        self.processed_image_path_label = QLabel("Original image", self)  # Define the processed_image_path_label
        self.processed_image_path_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        self.irm_label = QLabel("IRM Image", self)
        self.irm_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        label_layout.addWidget(self.processed_image_path_label)
        label_layout.addStretch(1)  # Add a flexible space between the labels
        label_layout.addWidget(self.irm_label)

        # Add the label layout to the main layout
        main_layout.addLayout(label_layout)

        # Set the main widget
        self.setCentralWidget(main_widget)

        # Create a label to display the image
        self.image_label = QLabel(self)
        main_layout.addWidget(self.image_label)  

        # Créez un bouton Clear en bas de l'interface
        clear_button = QPushButton("Clear")
        clear_button.setStyleSheet("background-color: white; color: black; font-weight: bold;")
        button_layout.addWidget(clear_button)

        # Connectez le signal clicked du bouton à la méthode clear_image_and_fields
        clear_button.clicked.connect(self.clear_image_and_fields)

        # Ajoutez un peu d'espace entre le bouton Clear et le bas de l'interface
        main_layout.addSpacing(20)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choose an image", "", "Image (*.png *.jpg *.jpeg *.bmp *.gif *tif)", options=options)
        if file_name:
            self.image_name_field.setText(file_name.split('/')[-1])  # Display only the file name
            self.image_path_field.setText(file_name)  # Display the full file path

            # Display the image
            pixmap = QPixmap(file_name)
            pixmap = pixmap.scaledToWidth(300)  # Resize the image for display
            self.image_label.setPixmap(pixmap)

    def compress_image(self):
        print("Compression in progress...")

    def decompress_image(self):
        print("Decompression in progress...")

    def show_image_info(self):
        file_path = self.image_path_field.text()
        if not file_path:
            QMessageBox.warning(self, "Warning", "Please select an image first.")
            return

        try:
            image = Image.open(file_path)
            info_str = f"Size: {image.size}\nFormat: {image.format}\nMode: {image.mode}"
            QMessageBox.information(self, "Image Information", info_str)
        except Exception as e:
            QMessageBox.warning(self, "Error", f"Unable to open the image: {str(e)}")

    def clear_image_and_fields(self):
        # Effacez l'image affichée
        self.image_label.clear()
        # Réinitialisez les champs de texte
        self.image_path_field.setText("")
        self.image_name_field.setText("")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog, QLineEdit, QMessageBox
from PyQt5.QtGui import QPixmap  # Added QPixmap import
from PIL import Image
import os

def details(path):
    img = Image.open(path)
    size = img.size
    format = img.format
    mode = img.mode
    resolution = img.info.get('dpi')
    definition = size[0] * size[1]
    definition2 = size
    if resolution is not None:
        size = (size[0]/ resolution[0], size[1] / resolution[1])
    else:
        size = (0, 0)  # or any default resolution you want to use
    
    poids = os.path.getsize(path) / (1000.0)  # Convert to kilobytes
    
    if mode == 'RGB':
        trsc = definition * 3 * img.bits
    else:
        trsc = definition * 1 * img.bits
    
    trsc /= (1024 * 8)
    
    taux_compression = 100 * (1 - (poids/trsc))
        
    return size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression

class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: #333333;")
        self.setWindowTitle("Image Compression")

        # Create a label to display the text
        self.label = QLabel("Image Extension", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Set the label as the central widget
        self.setCentralWidget(self.label)

        # Set the window size
        self.resize(700, 500)

        # Create a widget to contain buttons and text fields
        main_widget = QWidget()

        # Create a vertical layout for buttons and text fields
        main_layout = QVBoxLayout(main_widget)
        main_layout.setAlignment(Qt.AlignTop)

        # Create a gray frame to enclose the labels
        frame_style = "border: 2px solid gray; border-radius: 5px; background-color: #777777;"
        path_frame = QWidget()
        path_frame.setStyleSheet(frame_style)
        path_layout = QVBoxLayout(path_frame)

        # Add the label for the image path
        path_label = QLabel("Image Path:", self)
        path_label.setStyleSheet("color: white;")
        path_layout.addWidget(path_label)

        # Text field to display the image path
        self.image_path_field = QLineEdit(self)
        self.image_path_field.setReadOnly(True)
        self.image_path_field.setStyleSheet("background-color: gray; color: white;")  
        path_layout.addWidget(self.image_path_field)

        # Add the path frame to the main window
        main_layout.addWidget(path_frame)

        # Create a gray frame to enclose the labels
        name_frame = QWidget()
        name_frame.setStyleSheet(frame_style)
        name_layout = QVBoxLayout(name_frame)

        # Add the label for the image name
        name_label = QLabel("Image Name:", self)
        name_label.setStyleSheet("color: white;")
        name_layout.addWidget(name_label)

        # Text field to display the image name
        self.image_name_field = QLineEdit(self)
        self.image_name_field.setReadOnly(True)
        self.image_name_field.setStyleSheet("background-color: gray; color: white;")  
        name_layout.addWidget(self.image_name_field)

        # Add the name frame to the main window
        main_layout.addWidget(name_frame)

        # Create a widget to contain buttons
        button_widget = QWidget()

        # Create a vertical layout for buttons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Button to choose a file
        choose_button = QPushButton("Browse")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Button to display image information
        info_button = QPushButton("Information")
        info_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(info_button)

        # Add the button layout to the main window
        main_layout.addWidget(button_widget)

        # Buttons to choose the number of colors
        colors_button_layout = QHBoxLayout()
        palette_label = QLabel("Select the number of colors for the palette:", self)
        palette_label.setStyleSheet("color: white;")
        colors_button_layout.addWidget(palette_label)
        for num in [32, 64, 128]:
            button = QPushButton(str(num))
            button.clicked.connect(lambda _, n=num: self.set_num_colors(n))
            colors_button_layout.addWidget(button)

        # Add the color palette layout to the main window
        main_layout.addLayout(colors_button_layout)

        # Create a horizontal layout for compression and decompression buttons
        compress_decompress_layout = QHBoxLayout()

        # Button for compression
        compress_button = QPushButton("Start Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Button for decompression
        decompress_button = QPushButton("Save image.irm")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Add the horizontal layout to the vertical layout
        button_layout.addLayout(compress_decompress_layout)

        # Add the button widget to the main window
        main_layout.addWidget(button_widget)

        # Connect button signals to slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.decompress_image)
        info_button.clicked.connect(self.show_image_info)

        # Create a layout for "Original image" and "IRM Image" labels
        label_layout = QHBoxLayout()
        self.processed_image_path_label = QLabel("Original image", self)  # Define the processed_image_path_label
        self.processed_image_path_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        self.irm_label = QLabel("IRM Image", self)
        self.irm_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        label_layout.addWidget(self.processed_image_path_label)
        label_layout.addStretch(1)  # Add a flexible space between the labels
        label_layout.addWidget(self.irm_label)

        # Add the label layout to the main layout
        main_layout.addLayout(label_layout)

        # Set the main widget
        self.setCentralWidget(main_widget)

        # Create a label to display the image
        self.image_label = QLabel(self)
        main_layout.addWidget(self.image_label)  

        # Create a Clear button at the bottom of the interface
        clear_button = QPushButton("Clear")
        clear_button.setStyleSheet("background-color: white; color: black; font-weight: bold;")
        button_layout.addWidget(clear_button)

        # Connect the clicked signal of the button to the clear_image_and_fields method
        clear_button.clicked.connect(self.clear_image_and_fields)

        # Add some space between the Clear button and the bottom of the interface
        main_layout.addSpacing(20)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choose an image", "", "Image (*.png *.jpg *.jpeg *.bmp *.gif *tif)", options=options)
        if file_name:
            self.image_name_field.setText(file_name.split('/')[-1])  # Display only the file name
            self.image_path_field.setText(file_name)  # Display the full file path

            # Display the image
            pixmap = QPixmap(file_name)
            pixmap = pixmap.scaledToWidth(300)  # Resize the image for display
            self.image_label.setPixmap(pixmap)

    def compress_image(self):
        print("Compression in progress...")

    def decompress_image(self):
        print("Decompression in progress...")

    def show_image_info(self):
        file_path = self.image_path_field.text()
        if not file_path:
            QMessageBox.warning(self, "Warning", "Please select an image first.")
            return

        try:
            # Utilize the details() function to get information about the image
            size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression = details(file_path)

            # Create a text string with the obtained information
            info_str = f"Size (inch): {size}\nFormat: {format}\nMode: {mode}\nResolution: {resolution}\nDefinition (pixels): {definition}\nDéfinition (L * C): {definition2}\nTaille en mémoire avec compression: {poids} KB\nTaille réelle sans compression: {trsc/1024} MB\nTaux de compression: {taux_compression} %"

            # Display the information in a message box
            QMessageBox.information(self, "Image Information", info_str)
        except Exception as e:
            QMessageBox.warning(self, "Error", f"Unable to open the image: {str(e)}")

    def clear_image_and_fields(self):
        # Clear the displayed image
        self.image_label.clear()
        # Reset the text fields
        self.image_path_field.setText("")
        self.image_name_field.setText("")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# /tmp/ipykernel_54574/3439477962.py:33: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow):
# QSocketNotifier: Can only be used with threads started with QThread
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# ...

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog, QLineEdit, QMessageBox
from PyQt5.QtGui import QPixmap  # Added QPixmap import
from PIL import Image
import os

def details(path):
    img = Image.open(path)
    size = img.size
    format = img.format
    mode = img.mode
    resolution = img.info.get('dpi')
    definition = size[0] * size[1]
    definition2 = size
    if resolution is not None:
        size = (size[0]/ resolution[0], size[1] / resolution[1])
    else:
        size = (0, 0)  # or any default resolution you want to use
    
    poids = os.path.getsize(path) / (1000.0)  # Convert to kilobytes
    
    if mode == 'RGB':
        trsc = definition * 3 * img.bits
    else:
        trsc = definition * 1 * img.bits
    
    trsc /= (1024 * 8)
    
    taux_compression = 100 * (1 - (poids/trsc))
        
    return size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression

class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: #333333;")
        self.setWindowTitle("Image Compression")

        # Create a label to display the text
        self.label = QLabel("Image Extension", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Set the label as the central widget
        self.setCentralWidget(self.label)

        # Set the window size
        self.resize(700, 500)

        # Create a widget to contain buttons and text fields
        main_widget = QWidget()

        # Create a vertical layout for buttons and text fields
        main_layout = QVBoxLayout(main_widget)
        main_layout.setAlignment(Qt.AlignTop)

        # Create a gray frame to enclose the labels
        frame_style = "border: 2px solid gray; border-radius: 5px; background-color: #777777;"
        path_frame = QWidget()
        path_frame.setStyleSheet(frame_style)
        path_layout = QVBoxLayout(path_frame)

        # Add the label for the image path
        path_label = QLabel("Image Path:", self)
        path_label.setStyleSheet("color: white;")
        path_layout.addWidget(path_label)

        # Text field to display the image path
        self.image_path_field = QLineEdit(self)
        self.image_path_field.setReadOnly(True)
        self.image_path_field.setStyleSheet("background-color: gray; color: white;")  
        path_layout.addWidget(self.image_path_field)

        # Add the path frame to the main window
        main_layout.addWidget(path_frame)

        # Create a gray frame to enclose the labels
        name_frame = QWidget()
        name_frame.setStyleSheet(frame_style)
        name_layout = QVBoxLayout(name_frame)

        # Add the label for the image name
        name_label = QLabel("Image Name:", self)
        name_label.setStyleSheet("color: white;")
        name_layout.addWidget(name_label)

        # Text field to display the image name
        self.image_name_field = QLineEdit(self)
        self.image_name_field.setReadOnly(True)
        self.image_name_field.setStyleSheet("background-color: gray; color: white;")  
        name_layout.addWidget(self.image_name_field)

        # Add the name frame to the main window
        main_layout.addWidget(name_frame)

        # Create a widget to contain buttons
        button_widget = QWidget()

        # Create a vertical layout for buttons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Button to choose a file
        choose_button = QPushButton("Browse")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Button to display image information
        info_button = QPushButton("Information")
        info_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(info_button)

        # Add the button layout to the main window
        main_layout.addWidget(button_widget)

        # Buttons to choose the number of colors
        colors_button_layout = QHBoxLayout()
        palette_label = QLabel("Select the number of colors for the palette:", self)
        palette_label.setStyleSheet("color: white;")
        colors_button_layout.addWidget(palette_label)
        for num in [32, 64, 128]:
            button = QPushButton(str(num))
            button.clicked.connect(lambda _, n=num: self.set_num_colors(n))
            colors_button_layout.addWidget(button)

        # Add the color palette layout to the main window
        main_layout.addLayout(colors_button_layout)

        # Create a horizontal layout for compression and decompression buttons
        compress_decompress_layout = QHBoxLayout()

        # Button for compression
        compress_button = QPushButton("Start Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Button for decompression
        decompress_button = QPushButton("Save image.irm")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Add the horizontal layout to the vertical layout
        button_layout.addLayout(compress_decompress_layout)

        # Add the button widget to the main window
        main_layout.addWidget(button_widget)

        # Connect button signals to slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.save_compressed_image)  # Connect to the save_compressed_image method
        info_button.clicked.connect(self.show_image_info)

        # Create a layout for "Original image" and "IRM Image" labels
        label_layout = QHBoxLayout()
        self.processed_image_path_label = QLabel("Original image", self)  # Define the processed_image_path_label
        self.processed_image_path_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        self.irm_label = QLabel("IRM Image", self)
        self.irm_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        label_layout.addWidget(self.processed_image_path_label)
        label_layout.addStretch(1)  # Add a flexible space between the labels
        label_layout.addWidget(self.irm_label)

        # Add the label layout to the main layout
        main_layout.addLayout(label_layout)

        # Set the main widget
        self.setCentralWidget(main_widget)

        # Create a label to display the image
        self.image_label = QLabel(self)
        main_layout.addWidget(self.image_label)  

        # Create a Clear button at the bottom of the interface
        clear_button = QPushButton("Clear")
        clear_button.setStyleSheet("background-color: white; color: black; font-weight: bold;")
        button_layout.addWidget(clear_button)

        # Connect the clicked signal of the button to the clear_image_and_fields method
        clear_button.clicked.connect(self.clear_image_and_fields)

        # Add some space between the Clear button and the bottom of the interface
        main_layout.addSpacing(20)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choose an image", "", "Image (*.png *.jpg *.jpeg *.bmp *.gif *tif)", options=options)
        if file_name:
            self.image_name_field.setText(file_name.split('/')[-1])  # Display only the file name
            self.image_path_field.setText(file_name)  # Display the full file path

            # Display the image
            pixmap = QPixmap(file_name)
            pixmap = pixmap.scaledToWidth(300)  # Resize the image for display
            self.image_label.setPixmap(pixmap)

    def compress_image(self):
        print("Compression in progress...")

    def save_compressed_image(self):
        # Get the user-provided name for the compressed image
        file_path, _ = QFileDialog.getSaveFileName(self, "Save Compressed Image", "", "Image Files (*.png *.jpg *.jpeg *.bmp *.gif *tif)")
        if file_path:
            # Retrieve the compressed image from wherever it's stored after compression
            # Replace the next line with actual code to retrieve the compressed image
            compressed_image = None
            if compressed_image:
                # Save the compressed image with the user-provided name
                compressed_image.save(file_path)
                QMessageBox.information(self, "Success", "Compressed image saved successfully.")
            else:
                QMessageBox.warning(self, "Error", "No compressed image available to save.")
        else:
            QMessageBox.warning(self, "Warning", "Please provide a name to save the compressed image.")

    def show_image_info(self):
        file_path = self.image_path_field.text()
        if not file_path:
            QMessageBox.warning(self, "Warning", "Please select an image first.")
            return

        try:
            # Utilize the details() function to get information about the image
            size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression = details(file_path)

            # Create a text string with the obtained information
            info_str = f"Size (inch): {size}\nFormat: {format}\nMode: {mode}\nResolution: {resolution}\nDefinition (pixels): {definition}\nDéfinition (L * C): {definition2}\nTaille en mémoire avec compression: {poids} KB\nTaille réelle sans compression: {trsc/1024} MB\nTaux de compression: {taux_compression} %"

            # Display the information in a message box
            QMessageBox.information(self, "Image Information", info_str)
        except Exception as e:
            QMessageBox.warning(self, "Error", f"Unable to open the image: {str(e)}")

    def clear_image_and_fields(self):
        # Clear the displayed image
        self.image_label.clear()
        # Reset the text fields
        self.image_path_field.setText("")
        self.image_name_field.setText("")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# /tmp/ipykernel_55571/3692358511.py:33: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow):
# QSocketNotifier: Can only be used with threads started with QThread
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# ...

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QFileDialog, QLineEdit, QMessageBox
from PyQt5.QtGui import QPixmap  # Added QPixmap import
from PIL import Image
import os

def details(path):
    img = Image.open(path)
    size = img.size
    format = img.format
    mode = img.mode
    resolution = img.info.get('dpi')
    definition = size[0] * size[1]
    definition2 = size
    if resolution is not None:
        size = (size[0]/ resolution[0], size[1] / resolution[1])
    else:
        size = (0, 0)  # or any default resolution you want to use
    
    poids = os.path.getsize(path) / (1000.0)  # Convert to kilobytes
    
    if mode == 'RGB':
        trsc = definition * 3 * img.bits
    else:
        trsc = definition * 1 * img.bits
    
    trsc /= (1024 * 8)
    
    taux_compression = 100 * (1 - (poids/trsc))
        
    return size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression

class CustomSaveDialog(QFileDialog):
    def __init__(self, parent=None):
        super(CustomSaveDialog, self).__init__(parent)
        self.setOption(QFileDialog.DontUseNativeDialog)

    def accept(self):
        selected_files = self.selectedFiles()
        if selected_files:
            file_path = selected_files[0]
            self.done(1)  # Close the dialog

class MainWindow(QMainWindow):
    def __init__(self):
        super(MainWindow, self).__init__()
        self.setStyleSheet("background-color: #333333;")
        self.setWindowTitle("Image Compression")

        # Create a label to display the text
        self.label = QLabel("Image Extension", self)
        font = self.label.font()
        font.setPointSize(15)
        self.label.setFont(font)
        self.label.setStyleSheet("color: gray; font-weight: bold;")
        self.label.setAlignment(Qt.AlignHCenter)

        # Set the label as the central widget
        self.setCentralWidget(self.label)

        # Set the window size
        self.resize(700, 500)

        # Create a widget to contain buttons and text fields
        main_widget = QWidget()

        # Create a vertical layout for buttons and text fields
        main_layout = QVBoxLayout(main_widget)
        main_layout.setAlignment(Qt.AlignTop)

        # Create a gray frame to enclose the labels
        frame_style = "border: 2px solid gray; border-radius: 5px; background-color: #777777;"
        path_frame = QWidget()
        path_frame.setStyleSheet(frame_style)
        path_layout = QVBoxLayout(path_frame)

        # Add the label for the image path
        path_label = QLabel("Image Path:", self)
        path_label.setStyleSheet("color: white;")
        path_layout.addWidget(path_label)

        # Text field to display the image path
        self.image_path_field = QLineEdit(self)
        self.image_path_field.setReadOnly(True)
        self.image_path_field.setStyleSheet("background-color: gray; color: white;")  
        path_layout.addWidget(self.image_path_field)

        # Add the path frame to the main window
        main_layout.addWidget(path_frame)

        # Create a gray frame to enclose the labels
        name_frame = QWidget()
        name_frame.setStyleSheet(frame_style)
        name_layout = QVBoxLayout(name_frame)

        # Add the label for the image name
        name_label = QLabel("Image Name:", self)
        name_label.setStyleSheet("color: white;")
        name_layout.addWidget(name_label)

        # Text field to display the image name
        self.image_name_field = QLineEdit(self)
        self.image_name_field.setReadOnly(True)
        self.image_name_field.setStyleSheet("background-color: gray; color: white;")  
        name_layout.addWidget(self.image_name_field)

        # Add the name frame to the main window
        main_layout.addWidget(name_frame)

        # Create a widget to contain buttons
        button_widget = QWidget()

        # Create a vertical layout for buttons
        button_layout = QVBoxLayout(button_widget)
        button_layout.setAlignment(Qt.AlignTop)

        # Button to choose a file
        choose_button = QPushButton("Browse")
        choose_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(choose_button)

        # Button to display image information
        info_button = QPushButton("Information")
        info_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        button_layout.addWidget(info_button)

        # Add the button layout to the main window
        main_layout.addWidget(button_widget)

        # Buttons to choose the number of colors
        colors_button_layout = QHBoxLayout()
        palette_label = QLabel("Select the number of colors for the palette:", self)
        palette_label.setStyleSheet("color: white;")
        colors_button_layout.addWidget(palette_label)
        for num in [32, 64, 128]:
            button = QPushButton(str(num))
            button.clicked.connect(lambda _, n=num: self.set_num_colors(n))
            colors_button_layout.addWidget(button)

        # Add the color palette layout to the main window
        main_layout.addLayout(colors_button_layout)

        # Create a horizontal layout for compression and decompression buttons
        compress_decompress_layout = QHBoxLayout()

        # Button for compression
        compress_button = QPushButton("Start Compression")
        compress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(compress_button)

        # Button for decompression
        decompress_button = QPushButton("Save image.irm")
        decompress_button.setStyleSheet("background: qlineargradient(x1:0, y1:0, x2:1, y2:0, stop:0 #000000, stop:1 #AAAAAA); color: white; border: none; padding: 10px; text-align: center; text-decoration: none; display: inline-block; font-size: 16px; margin: 4px 2px; cursor: pointer; border-radius: 8px;")
        compress_decompress_layout.addWidget(decompress_button)

        # Add the horizontal layout to the vertical layout
        button_layout.addLayout(compress_decompress_layout)

        # Add the button widget to the main window
        main_layout.addWidget(button_widget)

        # Connect button signals to slots
        choose_button.clicked.connect(self.choose_image_file)
        compress_button.clicked.connect(self.compress_image)
        decompress_button.clicked.connect(self.save_compressed_image)  # Connect to the save_compressed_image method
        info_button.clicked.connect(self.show_image_info)

        # Create a layout for "Original image" and "IRM Image" labels
        label_layout = QHBoxLayout()
        self.processed_image_path_label = QLabel("Original image", self)  # Define the processed_image_path_label
        self.processed_image_path_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        self.irm_label = QLabel("IRM Image", self)
        self.irm_label.setStyleSheet("color: white; font-weight: bold; font-size: 18px;")
        label_layout.addWidget(self.processed_image_path_label)
        label_layout.addStretch(1)  # Add a flexible space between the labels
        label_layout.addWidget(self.irm_label)

        # Add the label layout to the main layout
        main_layout.addLayout(label_layout)

        # Set the main widget
        self.setCentralWidget(main_widget)

        # Create a label to display the image
        self.image_label = QLabel(self)
        main_layout.addWidget(self.image_label)  

        # Create a Clear button at the bottom of the interface
        clear_button = QPushButton("Clear")
        clear_button.setStyleSheet("background-color: white; color: black; font-weight: bold;")
        button_layout.addWidget(clear_button)

        # Connect the clicked signal of the button to the clear_image_and_fields method
        clear_button.clicked.connect(self.clear_image_and_fields)

        # Add some space between the Clear button and the bottom of the interface
        main_layout.addSpacing(20)

    def choose_image_file(self):
        options = QFileDialog.Options()
        options |= QFileDialog.DontUseNativeDialog
        file_name, _ = QFileDialog.getOpenFileName(self, "Choose an image", "", "Image (*.png *.jpg *.jpeg *.bmp *.gif *tif)", options=options)
        if file_name:
            self.image_name_field.setText(file_name.split('/')[-1])  # Display only the file name
            self.image_path_field.setText(file_name)  # Display the full file path

            # Display the image
            pixmap = QPixmap(file_name)
            pixmap = pixmap.scaledToWidth(300)  # Resize the image for display
            self.image_label.setPixmap(pixmap)

    def compress_image(self):
        print("Compression in progress...")

    def save_compressed_image(self):
        save_dialog = CustomSaveDialog(self)
        save_dialog.setNameFilter("Image Files (*.png *.jpg *.jpeg *.bmp *.gif *tif)")
        save_dialog.setWindowTitle("Save Compressed Image")
        if save_dialog.exec_() == QFileDialog.Accepted:
            file_path = save_dialog.selectedFiles()[0]
            # Replace the next line with actual code to retrieve the compressed image
            compressed_image = None
            if compressed_image:
                # Save the compressed image with the user-provided name
                compressed_image.save(file_path)
                QMessageBox.information(self, "Success", "Compressed image saved successfully.")
            else:
                QMessageBox.warning(self, "Error", "No compressed image available to save.")

    def show_image_info(self):
        file_path = self.image_path_field.text()
        if not file_path:
            QMessageBox.warning(self, "Warning", "Please select an image first.")
            return

        try:
            # Utilize the details() function to get information about the image
            size, format, mode, resolution, definition, definition2, poids, trsc, taux_compression = details(file_path)

            # Create a text string with the obtained information
            info_str = f"Size (inch): {size}\nFormat: {format}\nMode: {mode}\nResolution: {resolution}\nDefinition (pixels): {definition}\nDéfinition (L * C): {definition2}\nTaille en mémoire avec compression: {poids} KB\nTaille réelle sans compression: {trsc/1024} MB\nTaux de compression: {taux_compression} %"

            # Display the information in a message box
            QMessageBox.information(self, "Image Information", info_str)
        except Exception as e:
            QMessageBox.warning(self, "Error", f"Unable to open the image: {str(e)}")

    def clear_image_and_fields(self):
        # Clear the displayed image
        self.image_label.clear()
        # Reset the text fields
        self.image_path_field.setText("")
        self.image_name_field.setText("")

app = QApplication([])

window = MainWindow()
window.show()

app.exec_()
# Out:
# /tmp/ipykernel_3607/3904014339.py:33: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class CustomSaveDialog(QFileDialog):
# /tmp/ipykernel_3607/3904014339.py:44: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow):
# QSocketNotifier: Can only be used with threads started with QThread
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# Unknown property display
# Unknown property cursor
# ...
